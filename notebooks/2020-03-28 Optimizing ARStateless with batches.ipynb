# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import Image
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import os
import json
import numpy as onp
import jax
import pickle
import matplotlib.pyplot as plt
import pandas as pd
from timecast.learners import AR
from timecast.learners._ar import _ar_predict, _ar_batch_window
from timecast.utils.numpy import ecdf
from timecast.utils.losses import MeanSquareError
import torch
import matplotlib

plt.rcParams['figure.figsize'] = [20, 10]

import tqdm.notebook as tqdm
# Out:
# <style>.container { width:100% !important; }</style>
# /home/dsuo/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/lib/xla_bridge.py:123: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
def load_cfg(cfg_path):
    cfg = json.load(open(cfg_path, "r"))
    cfg["camels_root"] = Path(cfg["camels_root"])
    cfg["run_dir"] = Path(cfg["run_dir"])
    cfg.update(GLOBAL_SETTINGS)
    return cfg

# %%
import json
from pathlib import Path

from ealstm.main import GLOBAL_SETTINGS
from ealstm.main import get_basin_list
from ealstm.main import load_attributes
from ealstm.papercode.datasets import CamelsTXT

class FloodData():
    def __init__(self, cfg_path):
        self.cfg =load_cfg(cfg_path)
        self.basins = get_basin_list()
        self.db_path = os.path.join(self.cfg["run_dir"], "attributes.db")
        self.attributes = load_attributes(db_path=self.db_path,
                                          basins=self.basins,
                                          drop_lat_lon=True)
        
    def generator(self, is_train=False, with_attributes=True):
        for basin in self.basins:
            ds_test = CamelsTXT(camels_root=self.cfg["camels_root"],
                                basin=basin,
                                dates=[GLOBAL_SETTINGS["val_start"], GLOBAL_SETTINGS["val_end"]],
                                is_train=is_train,
                                seq_length=self.cfg["seq_length"],
                                with_attributes=True,
                                attribute_means=self.attributes.mean(),
                                attribute_stds=self.attributes.std(),
                                concat_static=self.cfg["concat_static"],
                                db_path=self.db_path,
                                reshape=False,
                                torchify=False
                               )
            X = np.concatenate((ds_test.x, np.tile(np.array(ds_test.attributes), (ds_test.x.shape[0], 1))), axis=1)
            yield X, ds_test.y, basin

# %%
import jax.numpy as np
from timecast.utils.losses.core import Loss

class BatchedMeanSquareError(Loss):
    def __init__(self):
        pass

    def compute(self, y_pred: np.ndarray, y_true: np.ndarray):
        return np.mean(np.mean((y_pred - y_true) ** 2, axis=tuple(range(1, y_true.ndim))))

# %%
import jax.numpy as np
import jax

from timecast.learners import BaseLearner

def batch_window(X, window_size, offset=0):
    num_windows = X.shape[0] - window_size + 1
    return np.swapaxes(np.stack([np.roll(X, shift=-(i + offset), axis=0) for i in range(window_size)]), 0, 1)[:num_windows]

class ARStateless(BaseLearner):
    def __init__(self, input_dim: int, output_dim: int, window_size: int, optimizer=None, loss=None):
        self._input_dim = input_dim
        self._output_dim = output_dim
        self._window_size = window_size
        self._optimizer = optimizer or SGD()
        self._loss = loss or BatchedMeanSquareError()
        
        W = np.zeros((window_size * input_dim + 1, output_dim))
        self._params = {"W": W}
        
        def _predict(params, x):
            squeeze = x.ndim == 2
            if squeeze:
                x = x[np.newaxis, :]
            shape = x.shape
            
            X = np.hstack((np.ones((shape[0], 1)), x.reshape(shape[0], -1))).reshape(shape[0], -1, 1)
            X = np.tensordot(X, params["W"], axes=(1, 0))
            return X.reshape(shape[0], -1)
        
        self._predict_jit = jax.jit(lambda params, X: _predict(params, X))
        self._grad = jax.jit(jax.grad(lambda params, X, y: self._loss.compute(_predict(params, X), y)))
        self._value_and_grad = jax.jit(jax.value_and_grad(lambda params, X, y: self._loss.compute(_predict(params, X), y)))
        
        def _predict_and_update(params, xy):
            value = self._predict_jit(params, xy[0])
            if value.shape[0] > 1:
                gradients = jax.vmap(self._grad, in_axes=({"W": None}, 0, 0), out_axes=0)(params, xy[0], xy[1])
                gradients = {key:val.mean(axis=0) for key, val in gradients.items()}
            else:
                gradients = self._grad(params, xy[0], xy[1])
            params = self._optimizer.update(params, gradients)
            return params, value
        
        self._predict_and_update_jit = jax.jit(lambda params, xy: _predict_and_update(params, xy))

    def predict(self, X):
        return jax.vmap(self._predict_jit, in_axes=(None, 0))(self._params, X).reshape(-1, 1)

    def update(self, X, y):
        gradients = jax.vmap(self._grad, in_axes=({"W": None}, 0, 0), out_axes=0)(self._params, X, y)
        gradients["W"] = gradients["W"].mean(axis=0)
        gradients["b"] = gradients["b"].mean(axis=0)
        self._params = self._optimizer.update(self._params, gradients)
        
    def predict_and_update(self, X, y, batch_size=1):
        last_batch_size = X.shape[0] % batch_size
        trim_size = X.shape[0] - last_batch_size
        trimmed_X = X[:trim_size].reshape((-1, batch_size) + X.shape[1:])
        trimmed_y = y[:trim_size].reshape((-1, batch_size) + y.shape[1:])
        self._params, value = jax.lax.scan(self._predict_and_update_jit, self._params, (trimmed_X, trimmed_y))
        value = value.reshape((value.shape[0] * value.shape[1],) + value.shape[2:])
        
        if last_batch_size > 0:
            last_X = X[trim_size:][np.newaxis, :]
            last_y = y[trim_size:][np.newaxis, :]
            self._params, trim_value = jax.lax.scan(self._predict_and_update_jit, self._params, (last_X, last_y))
            value = np.vstack((value, trim_value.squeeze(axis=0)))
        return value.reshape(-1, 1)

# %%
from ealstm.gaip import FloodLSTM
from ealstm.gaip import FloodData
from ealstm.gaip.utils import MSE, NSE

from timecast.optim import SGD
from timecast.learners import AR

cfg_path = "../data/models/runs/run_2006_0032_seed444/cfg.json"
flood_data = FloodData(cfg_path)
ea_data = pickle.load(open('../data/models/runs/run_2006_0032_seed444/lstm_seed444.p', "rb"))

LR_AR = 1e-5
AR_INPUT_DIM=32
AR_OUTPUT_DIM=1

# %%
# %%timeit
# %%prun -q -D out.pstats
results = {}
mses = []
nses = []
for X, _, basin in tqdm.tqdm(flood_data.generator(), total=len(flood_data.basins)):
    sgd = SGD(learning_rate=LR_AR, online=False)
    ar = ARStateless(input_dim=AR_INPUT_DIM, output_dim=AR_OUTPUT_DIM, window_size=flood_data.cfg["seq_length"], optimizer=sgd)
    X = batch_window(X, flood_data.cfg["seq_length"])
    Y = np.array(ea_data[basin].qobs).reshape(-1, 1)
    
    Y_lstm = np.array(ea_data[basin].qsim).reshape(-1, 1)
    Y_target = Y - Y_lstm
    
    Y_ar = ar.predict_and_update(X, Y_target, batch_size=1)
    
    Y_hat = Y_lstm + Y_ar
    
    mse = ((Y - Y_hat) ** 2).mean()
    nse = 1 - ((Y - Y_hat) ** 2).sum() / ((Y - Y.mean()) ** 2).sum()
    results[basin] = {
        "mse": mse,
        "nse": nse,
        "count": X.shape[0],
        "avg_mse": np.mean(np.array(mses)),
        "avg_nse": np.mean(np.array(nses))
    }
    mses.append(mse)
    nses.append(nse)
    print(basin, mse, nse, np.mean(np.array(mses)), np.mean(np.array(nses)))
# Out:
# HBox(children=(FloatProgress(value=0.0, max
# 02450250 4.7619376 0.79830164 1.9638885 0.73394746
# 02464000 2.930621 0.7422583 1.969893 0.733999
# 02464360 1.2306787 0.80513483 1.96533 0.7344381
# 02465493 1.5092679 0.62733823 1.9625319 0.7337811
# 02469800 1.6604192 0.832815 1.9606898 0.73438495
# 02472000 1.3112448 0.8640678 1.9567538 0.7351709
# 02472500 0.81668466 0.89914095 1.949886 0.7361587
# 02479155 6.0705748 0.6767037 1.9745607 0.7358027
# 02479300 1.6803375 0.8036434 1.9728094 0.73620653
# 02479560 1.3658031 0.84836113 1.9692175 0.7368701
# 02481000 6.3722224 0.74335706 1.9951175 0.7369083
# 02481510 2.4130614 0.80391026 1.9975618 0.73730016
# 04015330 2.252899 0.66174245 1.9990463 0.7368609
# 04024430 0.4891839 0.7830616 1.9903187 0.73712784
# 04027000 0.27036124 0.887639 1.9804341 0.7379929
# 04040500 0.33802435 0.8444825 1.971049 0.73860145
# 04043050 0.812655 0.8166368 1.9644669 0.7390448
# 04045500 0.02412607 0.97218746 1.9535044 0.740362
# 04057510 0.038344175 0.9494198 1.9427452 0.7415365
# 04057800 0.47224835 0.7852626 1.9345303 0.7417807
# 04059500 0.11727201 0.8931821 1.9244344 0.74262184
# 04063700 0.05912218 0.9114649 1.9141285 0.7435547
# 04074950 0.03584394 0.86431634 1.9038085 0.7442183
# 04105700 0.024202451 0.854716 1.8935375 0.744822
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-fb6343fb67d9> in <module>
#      13     Y_target = Y - Y_lstm
#      14
# ---> 15     Y_ar = ar.predict_and_update(X, Y_target, batch_size=1)
#      16
#      17     Y_hat = Y_lstm + Y_ar
#
# <ipython-input-5-13bc8b0c360e> in predict_and_update(self, X, y, batch_size)
#      59         trimmed_X = X[:trim_size].reshape((-1, batch_size) + X.shape[1:])
#      60         trimmed_y = y[:trim_size].reshape((-1, batch_size) + y.shape[1:])
# ---> 61         self._params, value = jax.lax.scan(self._predict_and_update_jit, self._params, (trimmed_X, trimmed_y))
#      62         value = value.reshape((value.shape[0] * value.shape[1],) + value.shape[2:])
#      63
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in scan(f, init, xs, length)
#     829                     forward=True, length=length, jaxpr=jaxpr,
#     830                     num_consts=len(consts), num_carry=len(init_flat),
# --> 831                     linear=(False,) * (len(consts) + len(in_flat)))
#     832   return tree_unflatten(out_tree, out)
#     833
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in scan_bind(forward, length, num_consts, num_carry, jaxpr, linear, *args)
#    1205   return core.Primitive.bind(scan_p, *args, forward=forward, length=length,
#    1206                              jaxpr=jaxpr, num_consts=num_consts,
# -> 1207                              num_carry=num_carry, linear=linear)
#    1208
#    1209 scan_p = core.Primitive("scan")
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/core.py in bind(self, *args, **kwargs)
#     197     top_trace = find_top_trace(args)
#     198     if top_trace is None:
# --> 199       return self.impl(*args, **kwargs)
#     200
#     201     tracers = map(top_trace.full_raise, args)
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _scan_impl(forward, length, num_consts, num_carry, jaxpr, linear, *args)
#     855   else:
#     856     init_val = [lax._const(length, 0)] + init + ys_init
# --> 857     _, *outs = while_loop(cond_fun, body_fun, init_val)
#     858     return outs
#     859
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in while_loop(cond_fun, body_fun, init_val)
#     214   init_avals = tuple(_map(_abstractify, init_vals))
#     215   cond_jaxpr, cond_consts, cond_tree = _initial_style_jaxpr(cond_fun, in_tree, init_avals)
# --> 216   body_jaxpr, body_consts, body_tree = _initial_style_jaxpr(body_fun, in_tree, init_avals)
#     217   if not treedef_is_leaf(cond_tree) or len(cond_jaxpr.out_avals) != 1:
#     218     msg = "cond_fun must return a boolean scalar, but got pytree {}."
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/lax/lax_control_flow.py in _initial_style_jaxpr(fun, in_tree, in_avals)
#      58   wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(fun), in_tree)
#      59   jaxpr, out_pvals, consts = pe.trace_to_jaxpr(
# ---> 60     wrapped_fun, in_pvals, instantiate=True, stage_out_calls=True)
#      61   out_avals = _map(raise_to_shaped, unzip2(out_pvals)[0])
#      62   const_avals = tuple(raise_to_shaped(core.get_aval(c)) for c in consts)
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_jaxpr(fun, pvals, instantiate, stage_out_calls, bottom)
#     356   with new_master(trace_type, bottom=bottom) as master:
#     357     fun = trace_to_subjaxpr(fun, master, instantiate)
# --> 358     jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     359     assert not env
#     360     del master
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/linear_util.py in call_wrapped(***failed resolving arguments***)
#     151     while stack:
#     152       gen, out_store = stack.pop()
# --> 153       ans = gen.send(ans)
#     154       if out_store is not None:
#     155         ans, side = ans
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in trace_to_subjaxpr(master, instantiate, pvals)
#     371   out_tracers = map(trace.full_raise, map(core.full_lower, ans))
#     372   out_tracers = map(partial(instantiate_const_at, trace), instantiate, out_tracers)
# --> 373   jaxpr, consts, env = tracers_to_jaxpr(in_tracers, out_tracers)
#     374   out_pvals = [t.pval for t in out_tracers]
#     375   del trace, in_tracers, out_tracers
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in tracers_to_jaxpr(in_tracers, out_tracers)
#     451     if isinstance(recipe, JaxprEqnRecipe):
#     452       if recipe.eqn_id not in processed_eqn_ids:
# --> 453         eqns.append(recipe_to_eqn(lambda: newvar(core.abstract_unit), getvar, recipe))
#     454         processed_eqn_ids.add(recipe.eqn_id)
#     455     elif isinstance(recipe, LambdaBinding):
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in recipe_to_eqn(unused_var, getvar, recipe)
#     411   out_tracers = [t_ref() for t_ref in out_tracer_refs]
#     412   invars  = [getvar(t) for t in in_tracers]
# --> 413   outvars = [unused_var() if t is None else getvar(t) for t in out_tracers]
#     414   return new_jaxpr_eqn(invars, outvars, primitive, params)
#     415
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in <listcomp>(.0)
#     411   out_tracers = [t_ref() for t_ref in out_tracer_refs]
#     412   invars  = [getvar(t) for t in in_tracers]
# --> 413   outvars = [unused_var() if t is None else getvar(t) for t in out_tracers]
#     414   return new_jaxpr_eqn(invars, outvars, primitive, params)
#     415
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/interpreters/partial_eval.py in getvar(t)
#     431     var = t_to_var.get(id(t))
#     432     if var is None:
# --> 433       var = newvar(partial_val_aval(*t.pval))
#     434       t_to_var[id(t)] = var
#     435     return var
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/core.py in <lambda>(aval)
#     147 def gensym(suffix):
#     148   counter = it.count()
# --> 149   return lambda aval: Var(next(counter), suffix, aval)
#     150
#     151 class Literal(object):
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/core.py in __init__(self, count, suffix, aval)
#     127     self.count = count
#     128     self.suffix = suffix
# --> 129     self.aval = raise_to_shaped(aval)
#     130
#     131   def __lt__(self, other):
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/core.py in raise_to_shaped(aval, weak_type)
#     822 def raise_to_shaped(aval, weak_type=False):
#     823   if isinstance(aval, ShapedArray):
# --> 824     return ShapedArray(aval.shape, aval.dtype, weak_type=weak_type)
#     825   elif aval is abstract_unit:
#     826     return abstract_unit
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/core.py in __init__(self, shape, dtype, weak_type)
#     712   def __init__(self, shape, dtype, weak_type=False):
#     713     super(ShapedArray, self).__init__(dtype, weak_type=weak_type)
# --> 714     self.shape = canonicalize_shape(shape)
#     715
#     716   ndim = property(lambda self: len(self.shape))
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/core.py in canonicalize_shape(shape)
#     849   """
#     850   try:
# --> 851     return tuple(map(_canonicalize_dimension, shape))
#     852   except TypeError:
#     853     pass
#
# ~/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/util.py in safe_map(f, *args)
#      28
#      29 def safe_map(f, *args):
# ---> 30   args = list(map(list, args))
#      31   n = len(args[0])
#      32   for arg in args[1:]:
#
# KeyboardInterrupt:
