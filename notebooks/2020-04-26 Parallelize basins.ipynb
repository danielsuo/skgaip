# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import Image
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import os
import json
import numpy as onp
import jax
import jax.numpy as jnp
import flax
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import torch
import matplotlib
import timecast as tc

from mpl_toolkits import mplot3d


plt.rcParams['figure.figsize'] = [20, 10]

import tqdm.notebook as tqdm
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Before parallelization

# %%
from ealstm.gaip.flood_data import FloodData

from timecast.learners._ar import _ar_gram
from timecast.learners._pcr import _compute_pca_projection

# Prepare training data
cfg_path = "../data/models/runs/run_2006_0032_seed444/cfg.json"
train_data = FloodData(cfg_path, is_train=True)

# Compute gram matrix for training data
XTX, XTY = _ar_gram(train_data.generator(), input_dim=32, output_dim=1, history_len=270)

# Compute PCA projection with k=10
k = 10
projection = _compute_pca_projection(XTX.matrix(normalize=True), k=k)
# Out:
# /home/dsuo/miniconda3/envs/toy_flood/lib/python3.7/site-packages/jax/lib/xla_bridge.py:123: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
import pickle
from ealstm.gaip.flood_data import FloodData
from ealstm.gaip.utils import MSE, NSE

import jax.numpy as jnp

from timecast.learners import Sequential, Parallel, Index, PCR
from timecast import smap
from timecast.objectives import residual
from timecast.optim import GradientDescent, RMSProp

import tqdm.notebook as tqdm

cfg_path = "../data/models/runs/run_2006_0032_seed444/cfg.json"
ea_data = pickle.load(open("../data/models/runs/run_2006_0032_seed444/lstm_seed444.p", "rb"))
flood_data = FloodData(cfg_path)

lr = 1e-5

results = {}
mses = []
nses = []

for X, _, basin in tqdm.tqdm(flood_data.generator(), total=531):
    lstm = Index.partial(index=0)
    pcr = PCR.partial(projection=projection, history_len=270, history=X[:flood_data.cfg["seq_length"] - 1])
    pcr = Sequential.partial(learners=[Index.partial(index=1), pcr])
    model, state = Parallel.new(shape=(1, 32), learners=[lstm, pcr])

    optim_def = GradientDescent(learning_rate=lr)
    optimizer = optim_def.create(model)

    # NOTE: difference in indexing convention, so need to pad one row
    X_t = X[flood_data.cfg["seq_length"]-1:]
    Y_lstm = jnp.array(ea_data[basin].qsim)
    Y = jnp.array(ea_data[basin].qobs).reshape(-1, 1)

    Y_hat, optimizer, state = smap((Y_lstm, X_t), Y, optimizer, state=state, objective=residual)
    model = optimizer.target

    mse = MSE(Y, Y_hat)
    nse = NSE(Y, Y_hat)
    mses.append(mse)
    nses.append(nse)

    results[basin] = {
        "mse": mse,
        "nse": nse,
        "count": X.shape[0],
        "avg_mse": jnp.mean(jnp.array(mses)),
        "avg_nse": jnp.mean(jnp.array(nses))
    }
    break
print({"basin": basin, "k": k, "mse": jnp.mean(jnp.array(mses))})

# %% [markdown]
# # After parallelization

# %%
import pickle

basins = pickle.load(open("../data/basins.p", "rb"))

# %%
@tc.experiment("k,projection", [(k, projection)])
@tc.experiment("basin", [(basin,) for basin in basins])
def runner(basin, k, projection, lr=1e-5):
    import pickle
    from ealstm.gaip.utils import MSE

    import jax.numpy as jnp

    from timecast.learners import Sequential, Parallel, Index, PCR
    from timecast import smap
    from timecast.objectives import residual
    from timecast.optim import GradientDescent

    import tqdm.notebook as tqdm
    
    X = pickle.load(open("../data/camels/{}.p".format(basin), "rb"))
    Y = pickle.load(open("../data/ealstm/{}.p".format(basin), "rb"))
    
    history_len = 270
    
    lstm = Index.partial(index=0)
    pcr = PCR.partial(projection=projection, history_len=history_len, history=X[:history_len - 1])
    pcr = Sequential.partial(learners=[Index.partial(index=1), pcr])
    model, state = Parallel.new(shape=(1, 32), learners=[lstm, pcr])
    
    optim_def = GradientDescent(learning_rate=lr)
    optimizer = optim_def.create(model)

    # NOTE: difference in indexing convention, so need to pad one row
    X_t = X[history_len - 1:]
    Y_lstm = jnp.array(Y.qsim)
    Y = jnp.array(Y.qobs).reshape(-1, 1)

    Y_hat, optimizer, state = smap((Y_lstm, X_t), Y, optimizer, state=state, objective=residual)

    return {"basin": basin, "k": k, "mse": MSE(Y, Y_hat)}

# %%
runner.run(processes=10, tqdm=tqdm)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# [{'basin': '01022500', 'k': 10, 'mse': array(0.8243627, dtype=float32)},
#  {'basin': '01031500', 'k': 10, 'mse': array(1.0610197, dtype=float32)},
#  {'basin': '01047000', 'k': 10, 'mse': array(1.308005, dtype=float32)},
#  {'basin': '01052500', 'k': 10, 'mse': array(2.0327582, dtype=float32)},
#  {'basin': '01054200', 'k': 10, 'mse': array(7.8569345, dtype=float32)},
#  {'basin': '01055000', 'k': 10, 'mse': array(4.757536, dtype=float32)},
#  {'basin': '01057000', 'k': 10, 'mse': array(0.93694293, dtype=float32)},
#  {'basin': '01073000', 'k': 10, 'mse': array(0.9335359, dtype=float32)},
#  {'basin': '01078000', 'k': 10, 'mse': array(0.69459224, dtype=float32)},
#  {'basin': '01123000', 'k': 10, 'mse': array(0.90753907, dtype=float32)},
#  {'basin': '01134500', 'k': 10, 'mse': array(1.7401067, dtype=float32)},
#  {'basin': '01137500', 'k': 10, 'mse': array(2.4031172, dtype=float32)},
#  {'basin': '01139000', 'k': 10, 'mse': array(0.8189094, dtype=float32)},
#  {'basin': '01139800', 'k': 10, 'mse': array(0.8540667, dtype=float32)},
#  {'basin': '01142500', 'k': 10, 'mse': array(1.1384416, dtype=float32)},
#  {'basin': '01144000', 'k': 10, 'mse': array(0.7445405, dtype=float32)},
#  {'basin': '01162500', 'k': 10, 'mse': array(0.82637876, dtype=float32)},
#  {'basin': '01169000', 'k': 10, 'mse': array(2.3246186, dtype=float32)},
#  {'basin': '01170100', 'k': 10, 'mse': array(1.8506126, dtype=float32)},
#  {'basin': '01181000', 'k': 10, 'mse': array(1.9514593, dtype=float32)},
#  {'basin': '01187300', 'k': 10, 'mse': array(2.781755, dtype=float32)},
#  {'basin': '01195100', 'k': 10, 'mse': array(2.0981572, dtype=float32)},
#  {'basin': '04296000', 'k': 10, 'mse': array(0.5654387, dtype=float32)},
#  {'basin': '01333000', 'k': 10, 'mse': array(0.72770214, dtype=float32)},
#  {'basin': '01350000', 'k': 10, 'mse': array(3.4191628, dtype=float32)},
#  {'basin': '01350080', 'k': 10, 'mse': array(2.0636706, dtype=float32)},
#  {'basin': '01350140', 'k': 10, 'mse': array(1.9656569, dtype=float32)},
#  {'basin': '01365000', 'k': 10, 'mse': array(2.196219, dtype=float32)},
#  {'basin': '01411300', 'k': 10, 'mse': array(0.24943087, dtype=float32)},
#  {'basin': '01413500', 'k': 10, 'mse': array(1.8992153, dtype=float32)},
#  {'basin': '01414500', 'k': 10, 'mse': array(2.5199637, dtype=float32)},
#  {'basin': '01415000', 'k': 10, 'mse': array(1.2831962, dtype=float32)},
#  {'basin': '01423000', 'k': 10, 'mse': array(1.1685613, dtype=float32)},
#  {'basin': '01434025', 'k': 10, 'mse': array(4.058423, dtype=float32)},
#  {'basin': '01435000', 'k': 10, 'mse': array(3.5427394, dtype=float32)},
#  {'basin': '01439500', 'k': 10, 'mse': array(0.593484, dtype=float32)},
#  {'basin': '01440000', 'k': 10, 'mse': array(0.7882379, dtype=float32)},
#  {'basin': '01440400', 'k': 10, 'mse': array(1.4186388, dtype=float32)},
#  {'basin': '01451800', 'k': 10, 'mse': array(1.6449054, dtype=float32)},
#  {'basin': '01466500', 'k': 10, 'mse': array(0.04355259, dtype=float32)},
#  {'basin': '01484100', 'k': 10, 'mse': array(0.67385143, dtype=float32)},
#  {'basin': '01487000', 'k': 10, 'mse': array(0.21599816, dtype=float32)},
#  {'basin': '01491000', 'k': 10, 'mse': array(0.7060077, dtype=float32)},
#  {'basin': '01510000', 'k': 10, 'mse': array(1.1630905, dtype=float32)},
#  {'basin': '01516500', 'k': 10, 'mse': array(3.101361, dtype=float32)},
#  {'basin': '01518862', 'k': 10, 'mse': array(2.3722026, dtype=float32)},
#  {'basin': '01532000', 'k': 10, 'mse': array(5.0542827, dtype=float32)},
#  {'basin': '01539000', 'k': 10, 'mse': array(1.0749981, dtype=float32)},
#  {'basin': '01542810', 'k': 10, 'mse': array(2.507429, dtype=float32)},
#  {'basin': '01543000', 'k': 10, 'mse': array(1.3365095, dtype=float32)},
#  {'basin': '01543500', 'k': 10, 'mse': array(0.8440121, dtype=float32)},
#  {'basin': '01544500', 'k': 10, 'mse': array(1.2759423, dtype=float32)},
#  {'basin': '01545600', 'k': 10, 'mse': array(0.9622028, dtype=float32)},
#  {'basin': '01547700', 'k': 10, 'mse': array(1.4755692, dtype=float32)},
#  {'basin': '01548500', 'k': 10, 'mse': array(0.74643475, dtype=float32)},
#  {'basin': '01549500', 'k': 10, 'mse': array(2.3108177, dtype=float32)},
#  {'basin': '01550000', 'k': 10, 'mse': array(3.0018473, dtype=float32)},
#  {'basin': '01552000', 'k': 10, 'mse': array(2.1041079, dtype=float32)},
#  {'basin': '01552500', 'k': 10, 'mse': array(4.3114724, dtype=float32)},
#  {'basin': '01557500', 'k': 10, 'mse': array(1.1388042, dtype=float32)},
#  {'basin': '01567500', 'k': 10, 'mse': array(2.6958106, dtype=float32)},
#  {'basin': '01568000', 'k': 10, 'mse': array(2.0667865, dtype=float32)},
#  {'basin': '01580000', 'k': 10, 'mse': array(0.85464126, dtype=float32)},
#  {'basin': '01583500', 'k': 10, 'mse': array(0.7396599, dtype=float32)},
#  {'basin': '01586610', 'k': 10, 'mse': array(1.1751833, dtype=float32)},
#  {'basin': '01591400', 'k': 10, 'mse': array(1.8436601, dtype=float32)},
#  {'basin': '01594950', 'k': 10, 'mse': array(2.017066, dtype=float32)},
#  {'basin': '01596500', 'k': 10, 'mse': array(1.9086775, dtype=float32)},
#  {'basin': '01605500', 'k': 10, 'mse': array(1.0518131, dtype=float32)},
#  {'basin': '01606500', 'k': 10, 'mse': array(1.2225332, dtype=float32)},
#  {'basin': '01632000', 'k': 10, 'mse': array(3.7928305, dtype=float32)},
#  {'basin': '01632900', 'k': 10, 'mse': array(1.4432982, dtype=float32)},
#  {'basin': '01634500', 'k': 10, 'mse': array(2.2365682, dtype=float32)},
#  {'basin': '01638480', 'k': 10, 'mse': array(2.1910725, dtype=float32)},
#  {'basin': '01639500', 'k': 10, 'mse': array(1.3363874, dtype=float32)},
#  {'basin': '01644000', 'k': 10, 'mse': array(1.042592, dtype=float32)},
#  {'basin': '01664000', 'k': 10, 'mse': array(1.3253626, dtype=float32)},
#  {'basin': '01666500', 'k': 10, 'mse': array(2.0453663, dtype=float32)},
#  {'basin': '01667500', 'k': 10, 'mse': array(1.3798279, dtype=float32)},
#  {'basin': '01669000', 'k': 10, 'mse': array(0.44405645, dtype=float32)},
#  {'basin': '01669520', 'k': 10, 'mse': array(0.4606045, dtype=float32)},
#  {'basin': '02011400', 'k': 10, 'mse': array(0.65012693, dtype=float32)},
#  {'basin': '02013000', 'k': 10, 'mse': array(1.0929531, dtype=float32)},
#  {'basin': '02014000', 'k': 10, 'mse': array(0.6689144, dtype=float32)},
#  {'basin': '02015700', 'k': 10, 'mse': array(1.6654887, dtype=float32)},
#  {'basin': '02016000', 'k': 10, 'mse': array(0.9609006, dtype=float32)},
#  {'basin': '02017500', 'k': 10, 'mse': array(0.8787734, dtype=float32)},
#  {'basin': '02018000', 'k': 10, 'mse': array(0.94278055, dtype=float32)},
#  {'basin': '02027000', 'k': 10, 'mse': array(2.949364, dtype=float32)},
#  {'basin': '02027500', 'k': 10, 'mse': array(6.4116106, dtype=float32)},
#  {'basin': '02028500', 'k': 10, 'mse': array(2.1237228, dtype=float32)},
#  {'basin': '02038850', 'k': 10, 'mse': array(2.5528755, dtype=float32)},
#  {'basin': '02046000', 'k': 10, 'mse': array(1.6342267, dtype=float32)},
#  {'basin': '02051500', 'k': 10, 'mse': array(0.5858572, dtype=float32)},
#  {'basin': '02053200', 'k': 10, 'mse': array(1.0068476, dtype=float32)},
#  {'basin': '02053800', 'k': 10, 'mse': array(1.1363285, dtype=float32)},
#  {'basin': '02055100', 'k': 10, 'mse': array(1.4129001, dtype=float32)},
#  {'basin': '02056900', 'k': 10, 'mse': array(1.0593352, dtype=float32)},
#  {'basin': '02059500', 'k': 10, 'mse': array(1.3646991, dtype=float32)},
#  {'basin': '02064000', 'k': 10, 'mse': array(3.1938024, dtype=float32)},
#  {'basin': '02065500', 'k': 10, 'mse': array(2.3037, dtype=float32)},
#  {'basin': '02069700', 'k': 10, 'mse': array(0.55582696, dtype=float32)},
#  {'basin': '02070000', 'k': 10, 'mse': array(0.9760585, dtype=float32)},
#  {'basin': '02074500', 'k': 10, 'mse': array(1.6688766, dtype=float32)},
#  {'basin': '02077200', 'k': 10, 'mse': array(9.669414, dtype=float32)},
#  {'basin': '02081500', 'k': 10, 'mse': array(1.7276677, dtype=float32)},
#  {'basin': '02082950', 'k': 10, 'mse': array(3.577394, dtype=float32)},
#  {'basin': '02092500', 'k': 10, 'mse': array(0.99448556, dtype=float32)},
#  {'basin': '02096846', 'k': 10, 'mse': array(3.0627997, dtype=float32)},
#  {'basin': '02102908', 'k': 10, 'mse': array(0.6071272, dtype=float32)},
#  {'basin': '02108000', 'k': 10, 'mse': array(0.53457516, dtype=float32)},
#  {'basin': '02111180', 'k': 10, 'mse': array(3.3910017, dtype=float32)},
#  {'basin': '02111500', 'k': 10, 'mse': array(1.7372736, dtype=float32)},
#  {'basin': '02112120', 'k': 10, 'mse': array(1.3443456, dtype=float32)},
#  {'basin': '02112360', 'k': 10, 'mse': array(1.0512834, dtype=float32)},
#  {'basin': '02118500', 'k': 10, 'mse': array(0.9689267, dtype=float32)},
#  {'basin': '02125000', 'k': 10, 'mse': array(5.620512, dtype=float32)},
#  {'basin': '02128000', 'k': 10, 'mse': array(5.1796513, dtype=float32)},
#  {'basin': '02137727', 'k': 10, 'mse': array(2.259818, dtype=float32)},
#  {'basin': '02140991', 'k': 10, 'mse': array(2.6623664, dtype=float32)},
#  {'basin': '02143000', 'k': 10, 'mse': array(1.7567304, dtype=float32)},
#  {'basin': '02143040', 'k': 10, 'mse': array(2.9467118, dtype=float32)},
#  {'basin': '02149000', 'k': 10, 'mse': array(0.932803, dtype=float32)},
#  {'basin': '02152100', 'k': 10, 'mse': array(1.8798982, dtype=float32)},
#  {'basin': '02177000', 'k': 10, 'mse': array(0.6020438, dtype=float32)},
#  {'basin': '02178400', 'k': 10, 'mse': array(1.6397599, dtype=float32)},
#  {'basin': '02193340', 'k': 10, 'mse': array(1.8725523, dtype=float32)},
#  {'basin': '02196000', 'k': 10, 'mse': array(0.84404176, dtype=float32)},
#  {'basin': '02198100', 'k': 10, 'mse': array(3.7444131, dtype=float32)},
#  {'basin': '02202600', 'k': 10, 'mse': array(0.9026814, dtype=float32)},
#  {'basin': '02212600', 'k': 10, 'mse': array(1.819687, dtype=float32)},
#  {'basin': '02215100', 'k': 10, 'mse': array(0.9041726, dtype=float32)},
#  {'basin': '02216180', 'k': 10, 'mse': array(2.0370202, dtype=float32)},
#  {'basin': '02221525', 'k': 10, 'mse': array(0.38462755, dtype=float32)},
#  {'basin': '02231000', 'k': 10, 'mse': array(0.13775063, dtype=float32)},
#  {'basin': '02245500', 'k': 10, 'mse': array(1.4815538, dtype=float32)},
#  {'basin': '02246000', 'k': 10, 'mse': array(1.0405481, dtype=float32)},
#  {'basin': '02296500', 'k': 10, 'mse': array(0.10809713, dtype=float32)},
#  {'basin': '02297155', 'k': 10, 'mse': array(1.8368702, dtype=float32)},
#  {'basin': '02297310', 'k': 10, 'mse': array(0.9754234, dtype=float32)},
#  {'basin': '02298123', 'k': 10, 'mse': array(0.2015022, dtype=float32)},
#  {'basin': '02298608', 'k': 10, 'mse': array(1.8087953, dtype=float32)},
#  {'basin': '02299950', 'k': 10, 'mse': array(7.3694544, dtype=float32)},
#  {'basin': '02300700', 'k': 10, 'mse': array(7.163671, dtype=float32)},
#  {'basin': '02342933', 'k': 10, 'mse': array(7.134538, dtype=float32)},
#  {'basin': '02349900', 'k': 10, 'mse': array(1.486456, dtype=float32)},
#  {'basin': '02350900', 'k': 10, 'mse': array(0.35145092, dtype=float32)},
#  {'basin': '02361000', 'k': 10, 'mse': array(2.696771, dtype=float32)},
#  {'basin': '02363000', 'k': 10, 'mse': array(0.9640774, dtype=float32)},
#  {'basin': '02369800', 'k': 10, 'mse': array(5.28874, dtype=float32)},
#  {'basin': '02371500', 'k': 10, 'mse': array(0.77266, dtype=float32)},
#  {'basin': '02372250', 'k': 10, 'mse': array(1.6090131, dtype=float32)},
#  {'basin': '02374500', 'k': 10, 'mse': array(1.1482149, dtype=float32)},
#  {'basin': '02381600', 'k': 10, 'mse': array(2.3555443, dtype=float32)},
#  {'basin': '02384540', 'k': 10, 'mse': array(6.8513374, dtype=float32)},
#  {'basin': '02395120', 'k': 10, 'mse': array(2.4751592, dtype=float32)},
#  {'basin': '02415000', 'k': 10, 'mse': array(1.5206311, dtype=float32)},
#  {'basin': '02427250', 'k': 10, 'mse': array(2.1283453, dtype=float32)},
#  {'basin': '02430085', 'k': 10, 'mse': array(8.177077, dtype=float32)},
#  {'basin': '02450250', 'k': 10, 'mse': array(4.735252, dtype=float32)},
#  {'basin': '02464000', 'k': 10, 'mse': array(2.9432328, dtype=float32)},
#  {'basin': '02464360', 'k': 10, 'mse': array(1.2385247, dtype=float32)},
#  {'basin': '02465493', 'k': 10, 'mse': array(1.5493068, dtype=float32)},
#  {'basin': '02469800', 'k': 10, 'mse': array(1.665693, dtype=float32)},
#  {'basin': '02472000', 'k': 10, 'mse': array(1.3368878, dtype=float32)},
#  {'basin': '02472500', 'k': 10, 'mse': array(0.81898785, dtype=float32)},
#  {'basin': '02479155', 'k': 10, 'mse': array(6.1046247, dtype=float32)},
#  {'basin': '02479300', 'k': 10, 'mse': array(1.7602135, dtype=float32)},
#  {'basin': '02479560', 'k': 10, 'mse': array(1.4106091, dtype=float32)},
#  {'basin': '02481000', 'k': 10, 'mse': array(6.4577627, dtype=float32)},
#  {'basin': '02481510', 'k': 10, 'mse': array(2.4357858, dtype=float32)},
#  {'basin': '04015330', 'k': 10, 'mse': array(2.2705572, dtype=float32)},
#  {'basin': '04024430', 'k': 10, 'mse': array(0.52227116, dtype=float32)},
#  {'basin': '04027000', 'k': 10, 'mse': array(0.28110355, dtype=float32)},
#  {'basin': '04040500', 'k': 10, 'mse': array(0.38995504, dtype=float32)},
#  {'basin': '04043050', 'k': 10, 'mse': array(0.83301115, dtype=float32)},
#  {'basin': '04045500', 'k': 10, 'mse': array(0.04576603, dtype=float32)},
#  {'basin': '04057510', 'k': 10, 'mse': array(0.06423187, dtype=float32)},
#  {'basin': '04057800', 'k': 10, 'mse': array(0.50414383, dtype=float32)},
#  {'basin': '04059500', 'k': 10, 'mse': array(0.12455654, dtype=float32)},
#  {'basin': '04063700', 'k': 10, 'mse': array(0.06770309, dtype=float32)},
#  {'basin': '04074950', 'k': 10, 'mse': array(0.03703993, dtype=float32)},
#  {'basin': '04105700', 'k': 10, 'mse': array(0.02536992, dtype=float32)},
#  {'basin': '04115265', 'k': 10, 'mse': array(0.11677893, dtype=float32)},
#  {'basin': '04122200', 'k': 10, 'mse': array(0.02776909, dtype=float32)},
#  {'basin': '04122500', 'k': 10, 'mse': array(0.0223722, dtype=float32)},
#  {'basin': '04127918', 'k': 10, 'mse': array(0.37566158, dtype=float32)},
#  {'basin': '04127997', 'k': 10, 'mse': array(0.03319174, dtype=float32)},
#  {'basin': '04161580', 'k': 10, 'mse': array(0.06573221, dtype=float32)},
#  {'basin': '04185000', 'k': 10, 'mse': array(0.2856046, dtype=float32)},
#  {'basin': '04196800', 'k': 10, 'mse': array(0.9707426, dtype=float32)},
#  {'basin': '04197100', 'k': 10, 'mse': array(0.76728326, dtype=float32)},
#  {'basin': '04197170', 'k': 10, 'mse': array(2.1753373, dtype=float32)},
#  {'basin': '04213000', 'k': 10, 'mse': array(2.333457, dtype=float32)},
#  {'basin': '04213075', 'k': 10, 'mse': array(3.4531245, dtype=float32)},
#  {'basin': '04216418', 'k': 10, 'mse': array(1.2952714, dtype=float32)},
#  {'basin': '04221000', 'k': 10, 'mse': array(1.0529349, dtype=float32)},
#  {'basin': '04224775', 'k': 10, 'mse': array(1.0512899, dtype=float32)},
#  {'basin': '04233000', 'k': 10, 'mse': array(1.1170958, dtype=float32)},
#  {'basin': '04256000', 'k': 10, 'mse': array(1.280298, dtype=float32)},
#  {'basin': '03010655', 'k': 10, 'mse': array(1.270986, dtype=float32)},
#  {'basin': '03011800', 'k': 10, 'mse': array(1.4083003, dtype=float32)},
#  {'basin': '03015500', 'k': 10, 'mse': array(1.1151639, dtype=float32)},
#  {'basin': '03021350', 'k': 10, 'mse': array(4.0777307, dtype=float32)},
#  {'basin': '03026500', 'k': 10, 'mse': array(1.74282, dtype=float32)},
#  {'basin': '03028000', 'k': 10, 'mse': array(1.3280208, dtype=float32)},
#  {'basin': '03049000', 'k': 10, 'mse': array(0.9103838, dtype=float32)},
#  {'basin': '03049800', 'k': 10, 'mse': array(1.399654, dtype=float32)},
#  {'basin': '03050000', 'k': 10, 'mse': array(2.2255085, dtype=float32)},
#  {'basin': '03069500', 'k': 10, 'mse': array(2.0910704, dtype=float32)},
#  {'basin': '03070500', 'k': 10, 'mse': array(1.5576884, dtype=float32)},
#  {'basin': '03076600', 'k': 10, 'mse': array(1.7056767, dtype=float32)},
#  {'basin': '03078000', 'k': 10, 'mse': array(2.2517161, dtype=float32)},
#  {'basin': '03140000', 'k': 10, 'mse': array(0.7362075, dtype=float32)},
#  {'basin': '03144000', 'k': 10, 'mse': array(0.9997084, dtype=float32)},
#  {'basin': '03170000', 'k': 10, 'mse': array(0.30941728, dtype=float32)},
#  {'basin': '03173000', 'k': 10, 'mse': array(0.7650887, dtype=float32)},
#  {'basin': '03180500', 'k': 10, 'mse': array(3.1593547, dtype=float32)},
#  {'basin': '03182500', 'k': 10, 'mse': array(1.047527, dtype=float32)},
#  {'basin': '03186500', 'k': 10, 'mse': array(2.7310944, dtype=float32)},
#  {'basin': '03237280', 'k': 10, 'mse': array(5.606447, dtype=float32)},
#  {'basin': '03237500', 'k': 10, 'mse': array(3.3015678, dtype=float32)},
#  {'basin': '03238500', 'k': 10, 'mse': array(3.838453, dtype=float32)},
#  {'basin': '03241500', 'k': 10, 'mse': array(0.508496, dtype=float32)},
#  {'basin': '03280700', 'k': 10, 'mse': array(3.4365668, dtype=float32)},
#  {'basin': '03281500', 'k': 10, 'mse': array(1.0483168, dtype=float32)},
#  {'basin': '03285000', 'k': 10, 'mse': array(6.7235723, dtype=float32)},
#  {'basin': '03291780', 'k': 10, 'mse': array(5.63781, dtype=float32)},
#  {'basin': '03338780', 'k': 10, 'mse': array(2.7362313, dtype=float32)},
#  {'basin': '03340800', 'k': 10, 'mse': array(1.2584642, dtype=float32)},
#  {'basin': '03346000', 'k': 10, 'mse': array(1.3460196, dtype=float32)},
#  {'basin': '03364500', 'k': 10, 'mse': array(1.7392213, dtype=float32)},
#  {'basin': '03366500', 'k': 10, 'mse': array(3.1448834, dtype=float32)},
#  {'basin': '03368000', 'k': 10, 'mse': array(9.119759, dtype=float32)},
#  {'basin': '03384450', 'k': 10, 'mse': array(5.400171, dtype=float32)},
#  {'basin': '03439000', 'k': 10, 'mse': array(1.6277944, dtype=float32)},
#  {'basin': '03455500', 'k': 10, 'mse': array(5.8258743, dtype=float32)},
#  {'basin': '03456500', 'k': 10, 'mse': array(2.8905673, dtype=float32)},
#  {'basin': '03460000', 'k': 10, 'mse': array(1.2704605, dtype=float32)},
#  {'basin': '03463300', 'k': 10, 'mse': array(4.8562775, dtype=float32)},
#  {'basin': '03471500', 'k': 10, 'mse': array(1.1453476, dtype=float32)},
#  {'basin': '03473000', 'k': 10, 'mse': array(0.7442728, dtype=float32)},
#  {'basin': '03479000', 'k': 10, 'mse': array(3.0324993, dtype=float32)},
#  {'basin': '03488000', 'k': 10, 'mse': array(1.6727275, dtype=float32)},
#  {'basin': '03498500', 'k': 10, 'mse': array(1.1632851, dtype=float32)},
#  {'basin': '03500000', 'k': 10, 'mse': array(0.610995, dtype=float32)},
#  {'basin': '03500240', 'k': 10, 'mse': array(0.95169413, dtype=float32)},
#  {'basin': '03504000', 'k': 10, 'mse': array(1.6375076, dtype=float32)},
#  {'basin': '03574500', 'k': 10, 'mse': array(4.972239, dtype=float32)},
#  {'basin': '03592718', 'k': 10, 'mse': array(10.859241, dtype=float32)},
#  {'basin': '03604000', 'k': 10, 'mse': array(3.944936, dtype=float32)},
#  {'basin': '05291000', 'k': 10, 'mse': array(0.25945053, dtype=float32)},
#  {'basin': '05362000', 'k': 10, 'mse': array(0.61268276, dtype=float32)},
#  {'basin': '05393500', 'k': 10, 'mse': array(1.0295192, dtype=float32)},
#  {'basin': '05399500', 'k': 10, 'mse': array(1.5103099, dtype=float32)},
#  {'basin': '05408000', 'k': 10, 'mse': array(0.09783626, dtype=float32)},
#  {'basin': '05413500', 'k': 10, 'mse': array(0.13900067, dtype=float32)},
#  {'basin': '05414000', 'k': 10, 'mse': array(0.41685656, dtype=float32)},
#  {'basin': '05444000', 'k': 10, 'mse': array(0.8295217, dtype=float32)},
#  {'basin': '05454000', 'k': 10, 'mse': array(4.1517253, dtype=float32)},
#  {'basin': '05458000', 'k': 10, 'mse': array(1.6882602, dtype=float32)},
#  {'basin': '05466500', 'k': 10, 'mse': array(0.4915634, dtype=float32)},
#  {'basin': '05487980', 'k': 10, 'mse': array(1.5097736, dtype=float32)},
#  {'basin': '05488200', 'k': 10, 'mse': array(2.1727123, dtype=float32)},
#  {'basin': '05489000', 'k': 10, 'mse': array(1.3866245, dtype=float32)},
#  {'basin': '05495000', 'k': 10, 'mse': array(1.197456, dtype=float32)},
#  {'basin': '05495500', 'k': 10, 'mse': array(3.019979, dtype=float32)},
#  {'basin': '05501000', 'k': 10, 'mse': array(2.5809915, dtype=float32)},
#  {'basin': '05503800', 'k': 10, 'mse': array(5.151737, dtype=float32)},
#  {'basin': '05507600', 'k': 10, 'mse': array(4.407211, dtype=float32)},
#  {'basin': '05508805', 'k': 10, 'mse': array(2.6209755, dtype=float32)},
#  {'basin': '05525500', 'k': 10, 'mse': array(0.86736625, dtype=float32)},
#  {'basin': '05556500', 'k': 10, 'mse': array(1.0270563, dtype=float32)},
#  {'basin': '05584500', 'k': 10, 'mse': array(0.58078384, dtype=float32)},
#  {'basin': '05591550', 'k': 10, 'mse': array(1.3424033, dtype=float32)},
#  {'basin': '05592050', 'k': 10, 'mse': array(2.3241446, dtype=float32)},
#  {'basin': '05592575', 'k': 10, 'mse': array(4.7992625, dtype=float32)},
#  {'basin': '05593575', 'k': 10, 'mse': array(2.3441534, dtype=float32)},
#  {'basin': '05593900', 'k': 10, 'mse': array(3.977326, dtype=float32)},
#  {'basin': '05595730', 'k': 10, 'mse': array(4.306218, dtype=float32)},
#  {'basin': '07291000', 'k': 10, 'mse': array(7.6809373, dtype=float32)},
#  {'basin': '07359610', 'k': 10, 'mse': array(11.715434, dtype=float32)},
#  {'basin': '07362100', 'k': 10, 'mse': array(3.3345118, dtype=float32)},
#  {'basin': '07362587', 'k': 10, 'mse': array(15.112981, dtype=float32)},
#  {'basin': '07375000', 'k': 10, 'mse': array(6.2925086, dtype=float32)},
#  {'basin': '08013000', 'k': 10, 'mse': array(2.5155804, dtype=float32)},
#  {'basin': '08014500', 'k': 10, 'mse': array(1.5335511, dtype=float32)},
#  {'basin': '05057200', 'k': 10, 'mse': array(0.06136927, dtype=float32)},
#  {'basin': '05120500', 'k': 10, 'mse': array(0.00522839, dtype=float32)},
#  {'basin': '06221400', 'k': 10, 'mse': array(0.12205644, dtype=float32)},
#  {'basin': '06224000', 'k': 10, 'mse': array(0.1941777, dtype=float32)},
#  {'basin': '06278300', 'k': 10, 'mse': array(0.7963514, dtype=float32)},
#  {'basin': '06280300', 'k': 10, 'mse': array(0.15772629, dtype=float32)},
#  {'basin': '06289000', 'k': 10, 'mse': array(0.03409725, dtype=float32)},
#  {'basin': '06291500', 'k': 10, 'mse': array(0.04514394, dtype=float32)},
#  {'basin': '06311000', 'k': 10, 'mse': array(0.16315535, dtype=float32)},
#  {'basin': '06332515', 'k': 10, 'mse': array(0.07501066, dtype=float32)},
#  {'basin': '06339100', 'k': 10, 'mse': array(0.12833282, dtype=float32)},
#  {'basin': '06344600', 'k': 10, 'mse': array(0.07732756, dtype=float32)},
#  {'basin': '06350000', 'k': 10, 'mse': array(0.03941914, dtype=float32)},
#  {'basin': '06352000', 'k': 10, 'mse': array(0.04684051, dtype=float32)},
#  {'basin': '06404000', 'k': 10, 'mse': array(0.22016995, dtype=float32)},
#  {'basin': '06406000', 'k': 10, 'mse': array(0.03698363, dtype=float32)},
#  {'basin': '06409000', 'k': 10, 'mse': array(0.00500154, dtype=float32)},
#  {'basin': '06431500', 'k': 10, 'mse': array(0.02311152, dtype=float32)},
#  {'basin': '06440200', 'k': 10, 'mse': array(0.25984257, dtype=float32)},
#  {'basin': '06447500', 'k': 10, 'mse': array(0.00945702, dtype=float32)},
#  {'basin': '06470800', 'k': 10, 'mse': array(0.23179407, dtype=float32)},
#  {'basin': '06477500', 'k': 10, 'mse': array(0.05741651, dtype=float32)},
#  {'basin': '06479215', 'k': 10, 'mse': array(0.5103398, dtype=float32)},
#  {'basin': '06601000', 'k': 10, 'mse': array(0.46049917, dtype=float32)},
#  {'basin': '06614800', 'k': 10, 'mse': array(1.1296532, dtype=float32)},
#  {'basin': '06622700', 'k': 10, 'mse': array(0.48400897, dtype=float32)},
#  {'basin': '06623800', 'k': 10, 'mse': array(0.28371167, dtype=float32)},
#  {'basin': '06632400', 'k': 10, 'mse': array(0.57392216, dtype=float32)},
#  {'basin': '06746095', 'k': 10, 'mse': array(4.098301, dtype=float32)},
#  {'basin': '06803510', 'k': 10, 'mse': array(1.6793627, dtype=float32)},
#  {'basin': '06803530', 'k': 10, 'mse': array(0.96554905, dtype=float32)},
#  {'basin': '06814000', 'k': 10, 'mse': array(1.8450744, dtype=float32)},
#  {'basin': '06847900', 'k': 10, 'mse': array(0.01529268, dtype=float32)},
#  {'basin': '06853800', 'k': 10, 'mse': array(0.12304825, dtype=float32)},
#  {'basin': '06876700', 'k': 10, 'mse': array(0.3095968, dtype=float32)},
#  {'basin': '06878000', 'k': 10, 'mse': array(0.86584496, dtype=float32)},
#  {'basin': '06879650', 'k': 10, 'mse': array(7.5831666, dtype=float32)},
#  {'basin': '06885500', 'k': 10, 'mse': array(1.3250788, dtype=float32)},
#  {'basin': '06888500', 'k': 10, 'mse': array(2.6461298, dtype=float32)},
#  {'basin': '06889200', 'k': 10, 'mse': array(1.678529, dtype=float32)},
#  {'basin': '06889500', 'k': 10, 'mse': array(1.7798235, dtype=float32)},
#  {'basin': '06892000', 'k': 10, 'mse': array(1.1142505, dtype=float32)},
#  {'basin': '06903400', 'k': 10, 'mse': array(2.309951, dtype=float32)},
#  {'basin': '06906800', 'k': 10, 'mse': array(4.3767037, dtype=float32)},
#  {'basin': '06910800', 'k': 10, 'mse': array(1.7278128, dtype=float32)},
#  {'basin': '06911900', 'k': 10, 'mse': array(1.9822673, dtype=float32)},
#  {'basin': '06917000', 'k': 10, 'mse': array(3.326311, dtype=float32)},
#  {'basin': '06918460', 'k': 10, 'mse': array(1.183032, dtype=float32)},
#  {'basin': '06919500', 'k': 10, 'mse': array(1.2939335, dtype=float32)},
#  {'basin': '06921070', 'k': 10, 'mse': array(1.9546188, dtype=float32)},
#  {'basin': '06921200', 'k': 10, 'mse': array(5.333368, dtype=float32)},
#  {'basin': '07057500', 'k': 10, 'mse': array(0.9845964, dtype=float32)},
#  {'basin': '07060710', 'k': 10, 'mse': array(1.6095589, dtype=float32)},
#  {'basin': '07066000', 'k': 10, 'mse': array(1.8827717, dtype=float32)},
#  {'basin': '07083000', 'k': 10, 'mse': array(0.15787794, dtype=float32)},
#  {'basin': '07142300', 'k': 10, 'mse': array(0.0162071, dtype=float32)},
#  {'basin': '07145700', 'k': 10, 'mse': array(1.4063511, dtype=float32)},
#  {'basin': '07167500', 'k': 10, 'mse': array(10.209215, dtype=float32)},
#  {'basin': '07180500', 'k': 10, 'mse': array(2.0283813, dtype=float32)},
#  {'basin': '07184000', 'k': 10, 'mse': array(8.0390415, dtype=float32)},
#  {'basin': '07195800', 'k': 10, 'mse': array(2.1072881, dtype=float32)},
#  {'basin': '07196900', 'k': 10, 'mse': array(8.049218, dtype=float32)},
#  {'basin': '07197000', 'k': 10, 'mse': array(1.9990281, dtype=float32)},
#  {'basin': '07208500', 'k': 10, 'mse': array(0.0477316, dtype=float32)},
#  {'basin': '07261000', 'k': 10, 'mse': array(3.1553905, dtype=float32)},
#  {'basin': '07263295', 'k': 10, 'mse': array(3.7371955, dtype=float32)},
#  {'basin': '07299670', 'k': 10, 'mse': array(0.8596944, dtype=float32)},
#  {'basin': '07301410', 'k': 10, 'mse': array(0.00565598, dtype=float32)},
#  {'basin': '07315200', 'k': 10, 'mse': array(1.7559683, dtype=float32)},
#  {'basin': '07315700', 'k': 10, 'mse': array(1.7586277, dtype=float32)},
#  {'basin': '07335700', 'k': 10, 'mse': array(20.026371, dtype=float32)},
#  {'basin': '07340300', 'k': 10, 'mse': array(11.472948, dtype=float32)},
#  {'basin': '07346045', 'k': 10, 'mse': array(0.46507135, dtype=float32)},
#  {'basin': '08023080', 'k': 10, 'mse': array(5.283556, dtype=float32)},
#  {'basin': '08050800', 'k': 10, 'mse': array(10.151767, dtype=float32)},
#  {'basin': '08066200', 'k': 10, 'mse': array(10.218144, dtype=float32)},
#  {'basin': '08066300', 'k': 10, 'mse': array(1.8505263, dtype=float32)},
#  {'basin': '08070000', 'k': 10, 'mse': array(4.3504667, dtype=float32)},
#  {'basin': '08070200', 'k': 10, 'mse': array(2.9432156, dtype=float32)},
#  {'basin': '08082700', 'k': 10, 'mse': array(0.2997849, dtype=float32)},
#  {'basin': '08086212', 'k': 10, 'mse': array(0.81483394, dtype=float32)},
#  {'basin': '08086290', 'k': 10, 'mse': array(0.6568887, dtype=float32)},
#  {'basin': '08101000', 'k': 10, 'mse': array(0.9098128, dtype=float32)},
#  {'basin': '08103900', 'k': 10, 'mse': array(1.5415347, dtype=float32)},
#  {'basin': '08104900', 'k': 10, 'mse': array(1.1300435, dtype=float32)},
#  {'basin': '08109700', 'k': 10, 'mse': array(0.81952214, dtype=float32)},
#  {'basin': '08150800', 'k': 10, 'mse': array(0.60829824, dtype=float32)},
#  {'basin': '08158700', 'k': 10, 'mse': array(0.9378231, dtype=float32)},
#  {'basin': '08158810', 'k': 10, 'mse': array(3.4293153, dtype=float32)},
#  {'basin': '08164300', 'k': 10, 'mse': array(2.6634486, dtype=float32)},
#  {'basin': '08164600', 'k': 10, 'mse': array(5.1545467, dtype=float32)},
#  {'basin': '08165300', 'k': 10, 'mse': array(0.4243848, dtype=float32)},
#  {'basin': '08171300', 'k': 10, 'mse': array(0.63189137, dtype=float32)},
#  {'basin': '08175000', 'k': 10, 'mse': array(1.0887744, dtype=float32)},
#  {'basin': '08176900', 'k': 10, 'mse': array(2.4867127, dtype=float32)},
#  {'basin': '08178880', 'k': 10, 'mse': array(0.70343316, dtype=float32)},
#  {'basin': '08189500', 'k': 10, 'mse': array(0.25061214, dtype=float32)},
#  {'basin': '08190000', 'k': 10, 'mse': array(0.75046647, dtype=float32)},
#  {'basin': '08190500', 'k': 10, 'mse': array(0.82843107, dtype=float32)},
#  {'basin': '08194200', 'k': 10, 'mse': array(0.06322787, dtype=float32)},
#  {'basin': '08195000', 'k': 10, 'mse': array(0.9553883, dtype=float32)},
#  {'basin': '08196000', 'k': 10, 'mse': array(1.4474406, dtype=float32)},
#  {'basin': '08198500', 'k': 10, 'mse': array(0.85419977, dtype=float32)},
#  {'basin': '08200000', 'k': 10, 'mse': array(3.8551981, dtype=float32)},
#  {'basin': '08202700', 'k': 10, 'mse': array(1.1142242, dtype=float32)},
#  {'basin': '08267500', 'k': 10, 'mse': array(0.05810092, dtype=float32)},
#  {'basin': '08269000', 'k': 10, 'mse': array(0.04155977, dtype=float32)},
#  {'basin': '08271000', 'k': 10, 'mse': array(0.09031785, dtype=float32)},
#  {'basin': '08324000', 'k': 10, 'mse': array(0.00804808, dtype=float32)},
#  {'basin': '08377900', 'k': 10, 'mse': array(0.22825138, dtype=float32)},
#  {'basin': '08378500', 'k': 10, 'mse': array(0.10479827, dtype=float32)},
#  {'basin': '08380500', 'k': 10, 'mse': array(0.19502535, dtype=float32)},
#  {'basin': '09035800', 'k': 10, 'mse': array(0.05133838, dtype=float32)},
#  {'basin': '09035900', 'k': 10, 'mse': array(0.07426593, dtype=float32)},
#  {'basin': '09047700', 'k': 10, 'mse': array(0.08700802, dtype=float32)},
#  {'basin': '09065500', 'k': 10, 'mse': array(0.47294608, dtype=float32)},
#  {'basin': '09066000', 'k': 10, 'mse': array(0.18317893, dtype=float32)},
#  {'basin': '09066200', 'k': 10, 'mse': array(0.507199, dtype=float32)},
#  {'basin': '09066300', 'k': 10, 'mse': array(0.09953907, dtype=float32)},
#  {'basin': '09081600', 'k': 10, 'mse': array(0.16039705, dtype=float32)},
#  {'basin': '09107000', 'k': 10, 'mse': array(0.03843782, dtype=float32)},
#  {'basin': '09210500', 'k': 10, 'mse': array(0.0353443, dtype=float32)},
#  {'basin': '09223000', 'k': 10, 'mse': array(0.09229822, dtype=float32)},
#  {'basin': '09306242', 'k': 10, 'mse': array(0.00235478, dtype=float32)},
#  {'basin': '09312600', 'k': 10, 'mse': array(0.01793079, dtype=float32)},
#  {'basin': '09352900', 'k': 10, 'mse': array(0.3365551, dtype=float32)},
#  {'basin': '09378170', 'k': 10, 'mse': array(0.03450594, dtype=float32)},
#  {'basin': '09386900', 'k': 10, 'mse': array(0.10444423, dtype=float32)},
#  {'basin': '09404450', 'k': 10, 'mse': array(0.00328684, dtype=float32)},
#  {'basin': '09430600', 'k': 10, 'mse': array(0.58775115, dtype=float32)},
#  {'basin': '09447800', 'k': 10, 'mse': array(0.33116853, dtype=float32)},
#  {'basin': '09484600', 'k': 10, 'mse': array(0.00629802, dtype=float32)},
#  {'basin': '09492400', 'k': 10, 'mse': array(0.11033543, dtype=float32)},
#  {'basin': '09494000', 'k': 10, 'mse': array(0.05398179, dtype=float32)},
#  {'basin': '09497980', 'k': 10, 'mse': array(0.11622943, dtype=float32)},
#  {'basin': '09505350', 'k': 10, 'mse': array(1.0717586, dtype=float32)},
#  {'basin': '09505800', 'k': 10, 'mse': array(0.7825552, dtype=float32)},
#  {'basin': '09508300', 'k': 10, 'mse': array(2.2918265, dtype=float32)},
#  {'basin': '09510200', 'k': 10, 'mse': array(0.33236262, dtype=float32)},
#  {'basin': '09512280', 'k': 10, 'mse': array(0.33818683, dtype=float32)},
#  {'basin': '09513780', 'k': 10, 'mse': array(1.8841298, dtype=float32)},
#  {'basin': '10234500', 'k': 10, 'mse': array(0.04113515, dtype=float32)},
#  {'basin': '10244950', 'k': 10, 'mse': array(0.01843988, dtype=float32)},
#  {'basin': '10336645', 'k': 10, 'mse': array(1.2388062, dtype=float32)},
#  {'basin': '10336660', 'k': 10, 'mse': array(5.4973025, dtype=float32)},
#  {'basin': '10343500', 'k': 10, 'mse': array(1.7228494, dtype=float32)},
#  {'basin': '12010000', 'k': 10, 'mse': array(13.484486, dtype=float32)},
#  {'basin': '12013500', 'k': 10, 'mse': array(6.7390823, dtype=float32)},
#  {'basin': '12020000', 'k': 10, 'mse': array(15.319486, dtype=float32)},
#  {'basin': '12025700', 'k': 10, 'mse': array(7.321416, dtype=float32)},
#  {'basin': '12035000', 'k': 10, 'mse': array(11.352307, dtype=float32)},
#  {'basin': '12040500', 'k': 10, 'mse': array(38.319683, dtype=float32)},
#  {'basin': '12041200', 'k': 10, 'mse': array(28.987919, dtype=float32)},
#  {'basin': '12048000', 'k': 10, 'mse': array(1.0926409, dtype=float32)},
#  {'basin': '12054000', 'k': 10, 'mse': array(10.231786, dtype=float32)},
#  {'basin': '12056500', 'k': 10, 'mse': array(24.209476, dtype=float32)},
#  {'basin': '12073500', 'k': 10, 'mse': array(1.0628463, dtype=float32)},
#  {'basin': '12082500', 'k': 10, 'mse': array(4.957114, dtype=float32)},
#  {'basin': '12092000', 'k': 10, 'mse': array(3.508548, dtype=float32)},
#  {'basin': '12114500', 'k': 10, 'mse': array(9.33796, dtype=float32)},
#  {'basin': '12115000', 'k': 10, 'mse': array(10.848965, dtype=float32)},
#  {'basin': '12117000', 'k': 10, 'mse': array(4.832259, dtype=float32)},
#  {'basin': '12143600', 'k': 10, 'mse': array(9.057203, dtype=float32)},
#  {'basin': '12144000', 'k': 10, 'mse': array(5.43341, dtype=float32)},
#  {'basin': '12145500', 'k': 10, 'mse': array(4.5030756, dtype=float32)},
#  {'basin': '12147500', 'k': 10, 'mse': array(12.1406, dtype=float32)},
#  {'basin': '12167000', 'k': 10, 'mse': array(19.053667, dtype=float32)},
#  {'basin': '12175500', 'k': 10, 'mse': array(3.9785886, dtype=float32)},
#  {'basin': '12178100', 'k': 10, 'mse': array(7.023502, dtype=float32)},
#  {'basin': '12186000', 'k': 10, 'mse': array(8.401923, dtype=float32)},
#  {'basin': '12189500', 'k': 10, 'mse': array(4.389664, dtype=float32)},
#  {'basin': '12375900', 'k': 10, 'mse': array(1.3196535, dtype=float32)},
#  {'basin': '12377150', 'k': 10, 'mse': array(1.3259007, dtype=float32)},
#  {'basin': '12381400', 'k': 10, 'mse': array(0.33522895, dtype=float32)},
#  {'basin': '12383500', 'k': 10, 'mse': array(0.08374502, dtype=float32)},
#  {'basin': '12390700', 'k': 10, 'mse': array(0.30720133, dtype=float32)},
#  {'basin': '12411000', 'k': 10, 'mse': array(1.1740693, dtype=float32)},
#  {'basin': '12447390', 'k': 10, 'mse': array(0.5375178, dtype=float32)},
#  {'basin': '12451000', 'k': 10, 'mse': array(1.4526469, dtype=float32)},
#  {'basin': '12488500', 'k': 10, 'mse': array(0.81220144, dtype=float32)},
#  {'basin': '13011500', 'k': 10, 'mse': array(0.66423094, dtype=float32)},
#  {'basin': '13011900', 'k': 10, 'mse': array(0.15525773, dtype=float32)},
#  {'basin': '13018300', 'k': 10, 'mse': array(0.07466635, dtype=float32)},
#  {'basin': '13023000', 'k': 10, 'mse': array(0.07284201, dtype=float32)},
#  {'basin': '13161500', 'k': 10, 'mse': array(0.00892199, dtype=float32)},
#  {'basin': '13235000', 'k': 10, 'mse': array(0.0985417, dtype=float32)},
#  {'basin': '13240000', 'k': 10, 'mse': array(1.1573242, dtype=float32)},
#  {'basin': '13313000', 'k': 10, 'mse': array(0.19724983, dtype=float32)},
#  {'basin': '13331500', 'k': 10, 'mse': array(0.37847388, dtype=float32)},
#  {'basin': '14020000', 'k': 10, 'mse': array(1.3246799, dtype=float32)},
#  {'basin': '14096850', 'k': 10, 'mse': array(0.22938173, dtype=float32)},
#  {'basin': '14137000', 'k': 10, 'mse': array(4.5273056, dtype=float32)},
#  {'basin': '14138800', 'k': 10, 'mse': array(20.043743, dtype=float32)},
#  {'basin': '14138870', 'k': 10, 'mse': array(9.278687, dtype=float32)},
#  {'basin': '14138900', 'k': 10, 'mse': array(20.246834, dtype=float32)},
#  {'basin': '14139800', 'k': 10, 'mse': array(13.290474, dtype=float32)},
#  {'basin': '14141500', 'k': 10, 'mse': array(6.7454004, dtype=float32)},
#  {'basin': '14154500', 'k': 10, 'mse': array(2.384531, dtype=float32)},
#  {'basin': '14158790', 'k': 10, 'mse': array(11.962767, dtype=float32)},
#  {'basin': '14166500', 'k': 10, 'mse': array(2.485639, dtype=float32)},
#  {'basin': '14182500', 'k': 10, 'mse': array(21.88248, dtype=float32)},
#  {'basin': '14185000', 'k': 10, 'mse': array(5.937623, dtype=float32)},
#  {'basin': '14185900', 'k': 10, 'mse': array(13.71242, dtype=float32)},
#  {'basin': '14187000', 'k': 10, 'mse': array(2.9299335, dtype=float32)},
#  {'basin': '14216500', 'k': 10, 'mse': array(12.412058, dtype=float32)},
#  {'basin': '14222500', 'k': 10, 'mse': array(8.043916, dtype=float32)},
#  {'basin': '14236200', 'k': 10, 'mse': array(9.052947, dtype=float32)},
#  {'basin': '14301000', 'k': 10, 'mse': array(2.885371, dtype=float32)},
#  {'basin': '14303200', 'k': 10, 'mse': array(13.946256, dtype=float32)},
#  {'basin': '14305500', 'k': 10, 'mse': array(15.118718, dtype=float32)},
#  {'basin': '14306340', 'k': 10, 'mse': array(9.271921, dtype=float32)},
#  {'basin': '14306500', 'k': 10, 'mse': array(3.7914364, dtype=float32)},
#  {'basin': '14308990', 'k': 10, 'mse': array(1.8512977, dtype=float32)},
#  {'basin': '14309500', 'k': 10, 'mse': array(3.4656336, dtype=float32)},
#  {'basin': '14316700', 'k': 10, 'mse': array(3.4756896, dtype=float32)},
#  {'basin': '14325000', 'k': 10, 'mse': array(8.38781, dtype=float32)},
#  {'basin': '14362250', 'k': 10, 'mse': array(0.18037304, dtype=float32)},
#  {'basin': '14400000', 'k': 10, 'mse': array(15.789037, dtype=float32)},
#  {'basin': '10259000', 'k': 10, 'mse': array(0.3590491, dtype=float32)},
#  {'basin': '11124500', 'k': 10, 'mse': array(1.3966408, dtype=float32)},
#  {'basin': '11141280', 'k': 10, 'mse': array(0.6362829, dtype=float32)},
#  {'basin': '11143000', 'k': 10, 'mse': array(2.6081808, dtype=float32)},
#  {'basin': '11148900', 'k': 10, 'mse': array(5.763281, dtype=float32)},
#  {'basin': '11151300', 'k': 10, 'mse': array(0.1387636, dtype=float32)},
#  {'basin': '11176400', 'k': 10, 'mse': array(0.9681403, dtype=float32)},
#  {'basin': '11230500', 'k': 10, 'mse': array(0.32328692, dtype=float32)},
#  {'basin': '11237500', 'k': 10, 'mse': array(2.049105, dtype=float32)},
#  {'basin': '11264500', 'k': 10, 'mse': array(0.8059228, dtype=float32)},
#  {'basin': '11266500', 'k': 10, 'mse': array(1.0124893, dtype=float32)},
#  {'basin': '11284400', 'k': 10, 'mse': array(2.449685, dtype=float32)},
#  {'basin': '11381500', 'k': 10, 'mse': array(3.277684, dtype=float32)},
#  {'basin': '11451100', 'k': 10, 'mse': array(8.895856, dtype=float32)},
#  {'basin': '11468500', 'k': 10, 'mse': array(5.7909346, dtype=float32)},
#  {'basin': '11473900', 'k': 10, 'mse': array(2.04, dtype=float32)},
#  {'basin': '11475560', 'k': 10, 'mse': array(13.815859, dtype=float32)},
#  {'basin': '11476600', 'k': 10, 'mse': array(10.2813635, dtype=float32)},
#  {'basin': '11478500', 'k': 10, 'mse': array(11.057005, dtype=float32)},
#  {'basin': '11480390', 'k': 10, 'mse': array(5.564434, dtype=float32)},
#  {'basin': '11481200', 'k': 10, 'mse': array(9.625851, dtype=float32)},
#  {'basin': '11482500', 'k': 10, 'mse': array(4.8149605, dtype=float32)},
#  {'basin': '11522500', 'k': 10, 'mse': array(0.6105564, dtype=float32)},
#  {'basin': '11523200', 'k': 10, 'mse': array(2.3819597, dtype=float32)},
#  {'basin': '11528700', 'k': 10, 'mse': array(1.8675288, dtype=float32)},
#  {'basin': '11532500', 'k': 10, 'mse': array(11.403696, dtype=float32)}]
